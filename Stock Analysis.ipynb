# %%
import warnings
warnings.filterwarnings('ignore')
from pandas_datareader import data as web
import datetime

stock = 'TSLA'
start_date = (datetime.datetime.now() - datetime.timedelta(days=365)).strftime("%m-%d-%Y")
df = web.DataReader(stock, data_source='yahoo', start=start_date)

# %%
import matplotlib.pyplot as plt
plt.plot(df['Close'])
plt.title("TSLA Stock Price in Past Year")
# Out:
# Text(0.5, 1.0, 'TSLA Stock Price in Past Year')

# %%
df.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-11-09  452.500000  421.000000  439.500000  421.260010  34833000.0
# 2020-11-10  420.089996  396.029999  420.089996  410.359985  30284200.0
# 2020-11-11  418.700012  410.579987  416.450012  417.130005  17357700.0
# 2020-11-12  423.000000  409.519989  415.049988  411.760010  19855100.0
# 2020-11-13  412.529999  401.660004  410.850006  408.500000  19771100.0
#
#              Adj Close
# Date
# 2020-11-09  421.260010
# 2020-11-10  410.359985
# 2020-11-11  417.130005
# 2020-11-12  411.760010
# 2020-11-13  408.500000

# %%
start_date = (datetime.datetime.now() - datetime.timedelta(days=1825)).strftime("%m-%d-%Y")
df = web.DataReader(stock, data_source='yahoo', start=start_date)
import matplotlib.pyplot as plt
plt.plot(df['Close'])
plt.title("TSLA Stock Price in Past 5 Years")
# Out:
# Text(0.5, 1.0, 'TSLA Stock Price in Past 5 Years')

# %%
stock = 'AMD'
start_date = (datetime.datetime.now() - datetime.timedelta(days=365)).strftime("%m-%d-%Y")
df = web.DataReader(stock, data_source='yahoo', start=start_date)
import matplotlib.pyplot as plt
plt.plot(df['Close'])
plt.title("AMD Stock Price in Recent Time")
# Out:
# Text(0.5, 1.0, 'AMD Stock Price in Recent Time')
